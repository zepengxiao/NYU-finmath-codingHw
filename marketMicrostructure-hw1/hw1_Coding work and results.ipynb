# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt
import pytz
from pytz import timezone
from datetime import timedelta
# %matplotlib inline

# %% [markdown]
# ### Problem 1.4

# %%
# Construct two data frames
# One called df1 collect all informations for CBL file on 2008-10-15
# The other called df2 collect all informations for CBL-NBBO file on 2008-10-15

def mytimeparser1(x):
    if (len(x) == 8):
        return dt.datetime.strptime(x + ".000", '%H:%M:%S.%f').replace(tzinfo=pytz.UTC).time()
    else:
        return dt.datetime.strptime(x, '%H:%M:%S.%f').replace(tzinfo=pytz.UTC).time()


df1 = pd.read_csv('CBL.2008-10-15', delimiter = '|', 
                 names = ('symbology','date','time','price','size','exchange',
                          'saleconditions','iscorrection','iscancel','isopen','isclose'),
                  parse_dates=['time'], date_parser = mytimeparser1)

df2 = pd.read_csv('CBL-NBBO.2008-10-15', delimiter = '|', 
                 names = ('symbology','timestamp','exchange','bidprice','bidsize',
                          'askprice','asksize','bestbidprice','bestbidsize','bestaskprice','bestasksize'),
                 encoding = "iso-8859-1", parse_dates = ['timestamp'] )
df2['timestamp'] = df2['timestamp'].dt.tz_convert('US/Eastern')
df2['time'] = df2['timestamp'].dt.time

df1
# Out:
#       symbology        date             time  price    size exchange  \
# 0           CBL  2008-10-15  09:29:57.014000  11.85    1000        T
# 1           CBL  2008-10-15  09:29:57.704000  11.86     100        T
# 2           CBL  2008-10-15  09:29:57.794000  11.86     900        T
# 3           CBL  2008-10-15  09:29:58.424000  11.86     100        T
# 4           CBL  2008-10-15  09:29:58.484000  11.86     900        T
# 5           CBL  2008-10-15  09:29:59.204000  11.86     100        T
# 6           CBL  2008-10-15  09:29:59.264000  11.86     100        P
# 7           CBL  2008-10-15  09:29:59.294000  11.86     500        T
# 8           CBL  2008-10-15  09:29:59.294000  11.86     300        P
# 9           CBL  2008-10-15  09:30:05.596000  11.86     100        P
# 10          CBL  2008-10-15  09:30:05.596000  11.86     900        P
# 11          CBL  2008-10-15  09:30:10.005000  10.81     100        P
# 12          CBL  2008-10-15  09:30:10.215000  11.05     100        P
# 13          CBL  2008-10-15  09:30:15.856000  10.95     100        T
# 14          CBL  2008-10-15  09:30:15.856000  10.95     100        T
# 15          CBL  2008-10-15  09:30:16.066000  10.93     100        P
# 16          CBL  2008-10-15  09:30:16.066000  10.92    1568        P
# 17          CBL  2008-10-15  09:31:36.021000  11.09     100        D
# 18          CBL  2008-10-15  09:31:58.100000  11.14     100        P
# 19          CBL  2008-10-15  09:31:58.100000  11.14     200        P
# 20          CBL  2008-10-15  09:31:58.250000  11.14     100        P
# 21          CBL  2008-10-15  09:31:59.210000  11.14     100        P
# 22          CBL  2008-10-15  09:32:25.735000  11.20     100        D
# 23          CBL  2008-10-15  09:32:26.785000  11.43     300        T
# 24          CBL  2008-10-15  09:32:26.785000  11.44     200        T
# 25          CBL  2008-10-15  09:32:26.815000  11.39     400        P
# 26          CBL  2008-10-15  09:32:26.815000  11.40     100        P
# 27          CBL  2008-10-15  09:32:31.765000  11.21     100        P
# 28          CBL  2008-10-15  09:32:33.085000  11.24     100        P
# 29          CBL  2008-10-15  09:32:34.525000  11.36    1000        P
# ...         ...         ...              ...    ...     ...      ...
# 10021       CBL  2008-10-15  15:59:49.406000   9.37     300        N
# 10022       CBL  2008-10-15  15:59:49.406000   9.36     100        N
# 10023       CBL  2008-10-15  15:59:49.436000   9.27    1000        N
# 10024       CBL  2008-10-15  15:59:50.186000   9.36     100        P
# 10025       CBL  2008-10-15  15:59:50.786000   9.36     100        N
# 10026       CBL  2008-10-15  15:59:52.316000   9.46     100        N
# 10027       CBL  2008-10-15  15:59:52.976000   9.36     200        N
# 10028       CBL  2008-10-15  15:59:53.427000   9.46     300        N
# 10029       CBL  2008-10-15  15:59:59.069000   9.37     100        D
# 10030       CBL  2008-10-15  16:00:03.777000   9.36     100        D
# 10031       CBL  2008-10-15  16:00:03.837000   9.36     100        D
# 10032       CBL  2008-10-15  16:00:12.448000   9.37     100        D
# 10033       CBL  2008-10-15  16:00:12.448000   9.37     100        D
# 10034       CBL  2008-10-15  16:00:12.448000   9.37     100        D
# 10035       CBL  2008-10-15  16:00:12.448000   9.36     100        D
# 10036       CBL  2008-10-15  16:00:12.448000   9.37     100        D
# 10037       CBL  2008-10-15  16:00:12.538000   9.37     200        D
# 10038       CBL  2008-10-15  16:00:12.628000   9.37     100        D
# 10039       CBL  2008-10-15  16:00:12.628000   9.37     100        D
# 10040       CBL  2008-10-15  16:00:16.918000   9.39     100        D
# 10041       CBL  2008-10-15  16:00:31.228000   9.37     200        T
# 10042       CBL  2008-10-15  16:01:59.073000   9.52    2200        N
# 10043       CBL  2008-10-15  16:02:02.463000   9.52   60300        N
# 10044       CBL  2008-10-15  16:17:08.933000   9.52     724        D
# 10045       CBL  2008-10-15  16:18:25.497000   9.52    2273        D
# 10046       CBL  2008-10-15  16:20:28.505000  10.59  146300        D
# 10047       CBL  2008-10-15  16:23:33.943000   9.52    3500        D
# 10048       CBL  2008-10-15  16:28:17.608000   9.52     400        T
# 10049       CBL  2008-10-15  16:59:07.796000   9.52   44495        D
# 10050       CBL  2008-10-15  17:01:00.241000   9.52   12398        D
#
#       saleconditions  iscorrection  iscancel  isopen  isclose
# 0                FT          False     False   False    False
# 1                FT          False     False   False    False
# 2                FT          False     False   False    False
# 3                FT          False     False   False    False
# 4                FT          False     False   False    False
# 5                FT          False     False   False    False
# 6                FT          False     False   False    False
# 7                FT          False     False   False    False
# 8                FT          False     False   False    False
# 9               @            False     False   False    False
# 10              @            False     False   False    False
# 11              @            False     False   False    False
# 12              @            False     False   False    False
# 13               F           False     False   False    False
# 14              Q            False     False   False    False
# 15               F           False     False   False    False
# 16               F           False     False   False    False
# 17              @            False     False   False    False
# 18              @            False     False   False    False
# 19              @            False     False   False    False
# 20              @            False     False   False    False
# 21               F           False     False   False    False
# 22              @            False     False   False    False
# 23               F           False     False   False    False
# 24               F           False     False   False    False
# 25               F           False     False   False    False
# 26               F           False     False   False    False
# 27              @            False     False   False    False
# 28               F           False     False   False    False
# 29              @            False     False   False    False
# ...              ...           ...       ...     ...      ...
# 10021           @            False     False   False    False
# 10022           F            False     False   False    False
# 10023           F            False     False   False    False
# 10024           @            False     False   False    False
# 10025           @            False     False   False    False
# 10026           @            False     False   False    False
# 10027           F            False     False   False    False
# 10028           @            False     False   False    False
# 10029           @            False     False   False    False
# 10030           @            False     False   False    False
# 10031           @            False     False   False    False
# 10032           @            False     False   False    False
# 10033           @            False     False   False    False
# 10034           @            False     False   False    False
# 10035           @            False     False   False    False
# 10036           @            False     False   False    False
# 10037            F           False     False   False    False
# 10038           @            False     False   False    False
# 10039           @            False     False   False    False
# 10040           @            False     False   False    False
# 10041           M            False     False   False    False
# 10042           @            False     False   False    False
# 10043             L          False     False   False    False
# 10044             T          False     False   False    False
# 10045             T          False     False   False    False
# 10046            4 B         False     False   False    False
# 10047              P         False     False   False    False
# 10048            FT          False     False   False    False
# 10049             TB         False     False   False    False
# 10050             TB         False     False   False    False
#
# [10051 rows x 11 columns]

# %% [markdown]
# #### Figure 1.3

# %%
# Work for figure 1.3
df1Trades = df1.loc[df1['exchange'] == 'N']
df1Trades = df1Trades.loc[df1Trades['iscancel'] == False]
# set x-axis as trade time and y-axis as trade price
plt.plot_date(x = df1Trades['time'], y = df1Trades['price'],markersize = 0.9, color = "darkblue")
plt.xticks([dt.time(10), dt.time(12), dt.time(14), dt.time(16)])
plt.title("NYSE Trades for CBL for the full continuous session on 2008-10-15")
plt.xlabel('time')
plt.ylabel('price')
plt.xlim(dt.time(9,25), dt.time(16,5))
plt.ylim(9.1, 11.7)
plt.grid(axis = 'x')
plt.show()

# %% [markdown]
# #### Figure 1.4

# %%
# Work for figure 1.4
# set time range between 9:33:30 and 9:35:00
df2TimeRange = df2[df2['time'].between(dt.time(9,33,30), dt.time(9,35))]
df2TimeRange = df2TimeRange.loc[df2TimeRange['exchange'] == 'N']
# set x-axis as trade time and y-axis as price
plt.plot_date(x = df2TimeRange['time'], y = df2TimeRange['bidprice'], markersize = 2.5, color = 'blue', label = 'Bid Quotes')
plt.plot_date(x = df2TimeRange['time'], y = df2TimeRange['askprice'], markersize = 2.5, color = 'purple', label = 'Ask Quotes')
plt.plot_date(x = df1Trades['time'], y = df1Trades['price'], marker = 'x', color = 'red', label = 'Trades')
plt.xticks([dt.time(9,34), dt.time(9,34,30)])
plt.title("NYSE Trades and quotes for CBL for the first few minutes of 2008-10-15")
plt.xlabel('time')
plt.ylabel('price')
plt.xlim(dt.time(9,33,35), dt.time(9,34,56))
plt.ylim(11.28,11.45)
plt.grid(axis = 'x')
plt.legend()
plt.show()

# %% [markdown]
# #### Figure 1.5

# %%
df2Spread = df2.loc[df2['exchange'] == 'N']
# set x-axis as trade time and y-axis as price
plt.plot_date(x = df2Spread['time'], y = df2Spread['askprice'] - df2Spread['bidprice'],markersize = 0.9, color = "darkblue")
plt.xticks([dt.time(10), dt.time(12), dt.time(14), dt.time(16)])
plt.title("The spread as of the last BBO for CBL on 2008-10-15")
plt.xlabel('time')
plt.ylabel('spread')
plt.xlim(dt.time(9,25), dt.time(16,10))
plt.grid(axis = 'x')
plt.show()

# %% [markdown]
# #### First-order autocovariance of the price changes and the implied spread in the Roll model

# %%
# retrieve all prices of trades that happend in 2008-10-15
priceP1 = df1Trades['price']
priceP1Change = np.array(priceP1.diff()) # compute all price changes
priceP1Change = priceP1Change[1:] # delete nan value
foCov = np.cov(priceP1Change[0:-1], priceP1Change[1:])[0][1] # compute auto covariance
impSpread = 2*np.sqrt(-foCov) # compute implied spread
print("The first-order autocovariance of the price changes is:", foCov)
print("The implied spread in the Roll model is:", impSpread)
# Out:
# The first-order autocovariance of the price changes is: -3.34226469868973e-05
# The implied spread in the Roll model is: 0.011562464613895655

# %% [markdown]
# #### Roll implied spread using rolling 30-minute intervals

# %%
# compute roll implied spread using rolling 30-minute intervals for 
# each time point when trade happened

# extract all columns that can be used to compute spread
timeP1 = np.array(df1Trades['time'])
priceP1 = np.array(priceP1)
# initialize an array of to record spread
lengthP1 = len(priceP1)
# cut off some ending value whose longest time intervals is far less than 30-min
spreadP1 = [0] * (lengthP1 - 200)
for i in range(lengthP1 - 200):
    currTimeP1 = timeP1[i]
    j = i
    # find the latest trade time that is in 30-min interval, 30 mins = 1800 seconds
    while (j < lengthP1 - 1 and (timeP1[j + 1].second - currTimeP1.second) + 60 * (timeP1[j + 1].minute - currTimeP1.minute) 
               + 3600 * (timeP1[j + 1].hour - currTimeP1.hour) <= 1800):
        j += 1
    # determine if the time range has enough price to compute auto-covariance
    if (j - i <= 2):
        spreadP1[i] = 0
    else:
        # compute auto-covariance and spread in this specific time range
        currCov = np.cov(priceP1Change[i:j - 1], priceP1Change[i + 1: j])[0][1]
        spreadP1[i] = 2*np.sqrt(abs(currCov)) 

# plot the result
plt.plot_date(x = timeP1[:-200], y = spreadP1, markersize = 0.9)
plt.xticks([dt.time(10), dt.time(12), dt.time(14), dt.time(16)])
plt.title("The roll implied spread using rolling 30-minute intervals on 2008-10-15")
plt.xlabel('time')
plt.ylabel('spread')
plt.grid()
plt.show()

# %% [markdown]
# ### Problem 2.2

# %%
# Construct two data frames
# One called dfCBL collect all informations for CBL file
# The other called dfNBBO collect all informations for CBL-NBBO file
dates = ['01', '02', '03', '06', '07', '08', '09', '10', '13', '14', '15', '16', 
        '17', '20', '21', '22', '23', '24', '27', '28', '29', '30']

def mytimeparser2(x):
    if (len(x) == 8):
        return dt.datetime.strptime(x + ".000", '%H:%M:%S.%f').replace(tzinfo=pytz.UTC).time()
    elif (len(x) == 5):
        return dt.datetime.strptime(x + ":00.000", '%H:%M:%S.%f').replace(tzinfo=pytz.UTC).time()
    else:
        return dt.datetime.strptime(x, '%H:%M:%S.%f').replace(tzinfo=pytz.UTC).time()

dfCBL = pd.read_csv('CBL.2008-10-01', delimiter = '|', 
                    names = ('symbology','date','time','price','size','exchange',
                             'saleconditions','iscorrection','iscancel','isopen','isclose'),
                    parse_dates=['time'], date_parser = mytimeparser2)
    
for date in dates[1:]:
    newdf = pd.read_csv('CBL.2008-10-' + date, delimiter = '|', 
                        names = ('symbology','date','time','price','size','exchange',
                                 'saleconditions','iscorrection','iscancel','isopen','isclose'),
                        parse_dates=['time'], date_parser = mytimeparser2)
    dfCBL = pd.concat([dfCBL, newdf], ignore_index=True)

dfNBBO = pd.read_csv('CBL-NBBO.2008-10-01', delimiter = '|', 
                     names = ('symbology','timestamp','exchange','bidprice','bidsize',
                              'askprice','asksize','bestbidprice','bestbidsize','bestaskprice','bestasksize'),
                     encoding = "iso-8859-1", parse_dates = ['timestamp'] )

for date in dates[1:]:
    newdf = pd.read_csv('CBL-NBBO.2008-10-' + date, delimiter = '|', 
                      names = ('symbology','timestamp','exchange','bidprice','bidsize',
                               'askprice','asksize','bestbidprice','bestbidsize','bestaskprice','bestasksize'),
                      encoding = "iso-8859-1", parse_dates = ['timestamp'] )
    dfNBBO = pd.concat([dfNBBO, newdf], ignore_index=True)

dfNBBO['timestamp'] = dfNBBO['timestamp'].dt.tz_convert('US/Eastern')
dfNBBO['time'] = dfNBBO['timestamp'].dt.time

# %%
# Work for problem 2.2
# extract all columns that can be used to tag trade
timeCBL = dfCBL['time']
priceCBL = dfCBL['price']
dateCBL = dfCBL['date']
dateNBBO = dfNBBO['timestamp']
timeNBBO = dfNBBO['time']
bidNBBO = dfNBBO['bestbidprice']
askNBBO = dfNBBO['bestaskprice']

# initialize an array of to record tag
length = len(priceCBL)
tradeCBL = [0] * length

# This function determine the trade given trade price and corresponding quote
# @input:
# currPrice: trade price
# bidPrice: bid price for the quote
# askPrice: ask price for the quote
# i: the index of the trade, specifying the order
# quote: a boolean to tell if we can do quote test, true means can, false means cannot
# @return: a tag that specify trade as "Buy" or "Sell" or "Cannot tell"
def tradeTag(currPrice, bidPrice, askPrice, i, quote):
    if (askPrice > bidPrice and quote): # check if spread exist and we can do quote test
        # spread exists, so apply quote test first, use midPrice as the classification price
        midPrice = (askPrice + bidPrice) / 2.0
        if (currPrice > midPrice):
            return "Buy"
        elif (currPrice < midPrice):
            return "Sell"
        else: # price equal to midPrice, apply tick test, find uptick or downtick
            prevI = i - 1
            # find a previous price that is different from current price
            while (priceCBL[prevI] == priceCBL[i] and prevI >= 1):
                prevI -= 1
            if (priceCBL[i] > priceCBL[prevI]):
                return "Buy"
            elif (priceCBL[i] < priceCBL[prevI]):
                return "Sell"
            else:
                # No previous price different from current price, tick test still fail
                return "Cannot tell"
    else:
        # spread does not exist or cannot do quote test, directly apply tick test
        prevI = i - 1
        # find a previous price that is different from current price
        while (priceCBL[prevI] == priceCBL[i] and prevI >= 1):
            prevI -= 1
        if (priceCBL[i] > priceCBL[prevI]):
            return "Buy"
        elif (priceCBL[i] < priceCBL[prevI]):
            return "Sell"
        else:
            # No previous price different from current price, tick test still fail
            return "Cannot tell"

j = 0 # j is the index in dfNBBO
for i in range(length): # i is the index in dfCBL
    if (not i):
        # current time and trade price
        currTime = timeCBL[i]
        currPrice = priceCBL[i]
        # find the quote whose time is before current time
        while ((currTime.second - timeNBBO[j + 1].second) + 60 * (currTime.minute - timeNBBO[j + 1].minute) 
               + 3600 * (currTime.hour - timeNBBO[j + 1].hour) >= 0):
            j += 1
        # record quote information
        bidPrice, askPrice = bidNBBO[j], askNBBO[j]
        # check if this quote could be the prevailing quote
        if ((currTime.second - timeNBBO[j + 1].second) + 60 * (currTime.minute - timeNBBO[j + 1].minute) 
               + 3600 * (currTime.hour - timeNBBO[j + 1].hour) <= 1):
            # this quote could be the prevailing quote, we can apply quote test
            tradeCBL[i] = tradeTag(currPrice, bidPrice, askPrice, i, True)
        else:
            # this quote could not be the prevailing quote, we cannot apply quote test
            tradeCBL[i] = tradeTag(currPrice, bidPrice, askPrice, i, False)
    else:
        # check if the date is changed
        if (dateCBL[i] != dateCBL[i - 1]):
            # if the date is changed, move j to the beginning of new date
            day = dt.datetime.strptime(dateCBL[i], '%Y-%m-%d').day
            while (dateNBBO[j].day < day):
                j += 1
            # current time and trade price
            currTime = timeCBL[i]
            currPrice = priceCBL[i]
            # check if the first quote of this date is before first trade
            if ((currTime.second - timeNBBO[j].second) + 60 * (currTime.minute - timeNBBO[j].minute) 
                   + 3600 * (currTime.hour - timeNBBO[j].hour) < 0):
                # the first quote of this date is after first trade, so no prevailing quote, cannot apply quote test
                bidPrice, askPrice = bidNBBO[j], askNBBO[j]
                tradeCBL[i] = tradeTag(currPrice, bidPrice, askPrice, i, False)
            else:
                # the first quote of this date is before first trade, prevailing quote may exist
                # find the quote whose time is before current time
                while ((currTime.second - timeNBBO[j + 1].second) + 60 * (currTime.minute - timeNBBO[j + 1].minute) 
                       + 3600 * (currTime.hour - timeNBBO[j + 1].hour) >= 0):
                    j += 1
                # record quote information
                bidPrice, askPrice = bidNBBO[j], askNBBO[j]
                # check if this quote could be the prevailing quote
                if ((currTime.second - timeNBBO[j + 1].second) + 60 * (currTime.minute - timeNBBO[j + 1].minute) 
                       + 3600 * (currTime.hour - timeNBBO[j + 1].hour) <= 1):
                    # this quote could be the prevailing quote, we can apply quote test
                    tradeCBL[i] = tradeTag(currPrice, bidPrice, askPrice, i, True)
                else:
                    # this quote could not be the prevailing quote, we cannot apply quote test
                    tradeCBL[i] = tradeTag(currPrice, bidPrice, askPrice, i, False)
        else:
            # current time and trade price
            currTime = timeCBL[i]
            currPrice = priceCBL[i]
            # find the quote whose time is before current time
            while ((currTime.second - timeNBBO[j + 1].second) + 60 * (currTime.minute - timeNBBO[j + 1].minute) 
                    + 3600 * (currTime.hour - timeNBBO[j + 1].hour) >= 0 and dateNBBO[j + 1].day == dateNBBO[j].day):
                j += 1
            # check if this quote could be the prevailing quote
            if ((currTime.second - timeNBBO[j + 1].second) + 60 * (currTime.minute - timeNBBO[j + 1].minute) 
                    + 3600 * (currTime.hour - timeNBBO[j + 1].hour) <= 1):
                # this quote could be the prevailing quote, we can apply quote test
                tradeCBL[i] = tradeTag(currPrice, bidPrice, askPrice, i, True)
            else:
                # this quote could not be the prevailing quote, we cannot apply quote test
                tradeCBL[i] = tradeTag(currPrice, bidPrice, askPrice, i, False)
                
# print results
print("Number of trades that tagged as buy =", tradeCBL.count("Buy"))
print("Number of trades that tagged as sell =", tradeCBL.count("Sell"))
# convert the tag array as a column of the data frame tradeCBL
dfCBL['tradeTag'] = tradeCBL 
dfCBL
# Out:
# Number of trades that tagged as buy = 76202
# Number of trades that tagged as sell = 189857
#        symbology        date             time    price   size exchange  \
# 0            CBL  2008-10-01  09:30:43.844000  19.8900    100        P
# 1            CBL  2008-10-01  09:31:07.575000  19.9100    284        D
# 2            CBL  2008-10-01  09:34:11.675000  19.7400    200        D
# 3            CBL  2008-10-01  09:35:02.216000  19.5800    700        T
# 4            CBL  2008-10-01  09:35:02.216000  19.5800    700        T
# 5            CBL  2008-10-01  09:35:05.816000  19.5800   1400        T
# 6            CBL  2008-10-01  09:35:07.556000  19.5800    100        T
# 7            CBL  2008-10-01  09:35:07.586000  19.5800    100        T
# 8            CBL  2008-10-01  09:35:08.096000  19.5800    100        P
# 9            CBL  2008-10-01  09:35:08.096000  19.5800    100        P
# 10           CBL  2008-10-01  09:35:08.126000  19.5800    200        T
# 11           CBL  2008-10-01  09:35:10.797000  19.5900    100        T
# 12           CBL  2008-10-01  09:35:11.097000  19.4000    100        T
# 13           CBL  2008-10-01  09:35:11.127000  19.6200    200        P
# 14           CBL  2008-10-01  09:35:11.127000  19.6200    100        P
# 15           CBL  2008-10-01  09:35:11.277000  19.6300    100        P
# 16           CBL  2008-10-01  09:35:11.727000  19.6100    100        T
# 17           CBL  2008-10-01  09:35:45.891000  19.8000    200        T
# 18           CBL  2008-10-01  09:37:16.763000  19.7800   3000        N
# 19           CBL  2008-10-01  09:37:16.853000  19.6300    200        T
# 20           CBL  2008-10-01  09:37:16.853000  19.6300    100        T
# 21           CBL  2008-10-01  09:37:35.515000  19.6900    100        P
# 22           CBL  2008-10-01  09:37:35.754000  19.7000    200        N
# 23           CBL  2008-10-01  09:37:40.855000  19.7900    100        T
# 24           CBL  2008-10-01  09:37:41.455000  19.7500    100        N
# 25           CBL  2008-10-01  09:37:42.505000  19.7500    100        N
# 26           CBL  2008-10-01  09:37:44.665000  19.7000    100        I
# 27           CBL  2008-10-01  09:37:44.665000  19.7200    200        D
# 28           CBL  2008-10-01  09:37:44.695000  19.7200    200        T
# 29           CBL  2008-10-01  09:37:44.695000  19.7200    100        T
# ...          ...         ...              ...      ...    ...      ...
# 266029       CBL  2008-10-30  15:59:26.706000   8.2600    100        D
# 266030       CBL  2008-10-30  15:59:27.336000   8.2900    111        P
# 266031       CBL  2008-10-30  15:59:31.119000   8.2900    200        P
# 266032       CBL  2008-10-30  15:59:31.119000   8.2900    100        P
# 266033       CBL  2008-10-30  15:59:31.449000   8.2900    193        T
# 266034       CBL  2008-10-30  15:59:35.080000   8.2900    100        N
# 266035       CBL  2008-10-30  15:59:35.380000   8.2900    100        N
# 266036       CBL  2008-10-30  15:59:42.219000   8.2900    200        P
# 266037       CBL  2008-10-30  15:59:42.429000   8.2900    200        N
# 266038       CBL  2008-10-30  15:59:42.459000   8.2900    200        D
# 266039       CBL  2008-10-30  15:59:42.789000   8.2600    100        T
# 266040       CBL  2008-10-30  15:59:45.790000   8.2900    200        D
# 266041       CBL  2008-10-30  15:59:45.970000   8.2600    100        P
# 266042       CBL  2008-10-30  15:59:46.090000   8.2600    200        P
# 266043       CBL  2008-10-30  15:59:48.160000   8.2900    200        D
# 266044       CBL  2008-10-30  15:59:48.850000   8.2900    433        T
# 266045       CBL  2008-10-30  15:59:48.970000   8.2900    100        P
# 266046       CBL  2008-10-30  15:59:50.500000   8.2600    100        P
# 266047       CBL  2008-10-30  15:59:52.421000   8.2792   1000        D
# 266048       CBL  2008-10-30  15:59:52.961000   8.2900    100        D
# 266049       CBL  2008-10-30  15:59:52.991000   8.2900    200        N
# 266050       CBL  2008-10-30  15:59:53.081000   8.2900    100        N
# 266051       CBL  2008-10-30  15:59:53.081000   8.2900    100        N
# 266052       CBL  2008-10-30  16:00:00.042000   8.2600    100        N
# 266053       CBL  2008-10-30  16:00:00.221000   8.2600    100        N
# 266054       CBL  2008-10-30  16:00:07.391000   8.2600    100        N
# 266055       CBL  2008-10-30  16:00:17.171000   8.2900    433        T
# 266056       CBL  2008-10-30  16:05:54.119000   8.2900   6600        N
# 266057       CBL  2008-10-30  16:05:57.809000   8.2900  99900        N
# 266058       CBL  2008-10-30  16:34:43.441000   8.2900   7846        D
#
#        saleconditions  iscorrection  iscancel  isopen  isclose tradeTag
# 0                @            False     False   False    False     Sell
# 1                 F           False     False   False    False     Sell
# 2                 F           False     False   False    False     Sell
# 3                 F           False     False   False    False     Sell
# 4                Q            False     False   False    False     Sell
# 5                 F           False     False   False    False     Sell
# 6                 F           False     False   False    False     Sell
# 7                 F           False     False   False    False     Sell
# 8                 F           False     False   False    False     Sell
# 9                 F           False     False   False    False     Sell
# 10                F           False     False   False    False     Sell
# 11                F           False     False   False    False     Sell
# 12               @            False     False   False    False     Sell
# 13                F           False     False   False    False     Sell
# 14                F           False     False   False    False     Sell
# 15                F           False     False   False    False     Sell
# 16                F           False     False   False    False     Sell
# 17                F           False     False   False    False     Sell
# 18               @            False     False   False    False     Sell
# 19                F           False     False   False    False     Sell
# 20                F           False     False   False    False     Sell
# 21                F           False     False   False    False     Sell
# 22               F            False     False   False    False     Sell
# 23                F           False     False   False    False     Sell
# 24               @            False     False   False    False     Sell
# 25               @            False     False   False    False     Sell
# 26                F           False     False   False    False     Sell
# 27                F           False     False   False    False     Sell
# 28                F           False     False   False    False     Sell
# 29                F           False     False   False    False     Sell
# ...               ...           ...       ...     ...      ...      ...
# 266029           @            False     False   False    False     Sell
# 266030           @            False     False   False    False     Sell
# 266031           @            False     False   False    False     Sell
# 266032           @            False     False   False    False     Sell
# 266033            F           False     False   False    False     Sell
# 266034           @            False     False   False    False     Sell
# 266035           @            False     False   False    False     Sell
# 266036            F           False     False   False    False     Sell
# 266037           @            False     False   False    False     Sell
# 266038           @            False     False   False    False     Sell
# 266039            F           False     False   False    False     Sell
# 266040           @            False     False   False    False     Sell
# 266041            F           False     False   False    False     Sell
# 266042           @            False     False   False    False     Sell
# 266043           @            False     False   False    False     Sell
# 266044            F           False     False   False    False     Sell
# 266045           @            False     False   False    False     Sell
# 266046            F           False     False   False    False     Sell
# 266047           @            False     False   False    False     Sell
# 266048           @            False     False   False    False     Sell
# 266049           @            False     False   False    False     Sell
# 266050           @            False     False   False    False     Sell
# 266051           @            False     False   False    False     Sell
# 266052           @            False     False   False    False     Sell
# 266053           @            False     False   False    False     Sell
# 266054           @            False     False   False    False     Sell
# 266055           M            False     False   False    False     Sell
# 266056           @            False     False   False    False     Sell
# 266057           @            False     False   False    False     Sell
# 266058             TB         False     False   False    False     Sell
#
# [266059 rows x 12 columns]

# %%
# Work for problem 2.3
# initial delta and mu
delta, mu = [0.5], 0.05

# update delta by the tag we have
for i in range(1, length):
    if (tradeCBL[i] == "Buy"):
        nextDelta = delta[-1]*((1-mu)/(-2*delta[-1]*mu + mu + 1))
        delta.append(nextDelta)
    else:
        nextDelta = delta[-1]*((1 + mu)/(2*delta[-1]*mu - mu + 1))
        delta.append(nextDelta)
        
# construct an array to display date time for each trade
dateTimeCBL = [dt.datetime.combine(dt.datetime.strptime(dateCBL[i], '%Y-%m-%d'), timeCBL[i]) for i in range(length)]

# plot results
fig = plt.figure(figsize = (16,12))
ax1 = plt.subplot(211)
ax2 = plt.subplot(212, sharex = ax1)
ax1.plot_date(x = dateTimeCBL, y = delta, markersize = 1)
ax2.plot_date(x = dateTimeCBL, y = priceCBL, markersize = 1)
ax1.set_title('The sequence delta_k (prob that price goes down) for the whole month')
ax2.set_title('The actual price')
#plt.savefig('Problem3.2.png')
# Out:
# Text(0.5, 1.0, 'The actual price')
